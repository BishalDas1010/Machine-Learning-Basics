# %% [markdown]
# <a href="https://colab.research.google.com/github/BishalDas1010/Machine-Learning-Basics/blob/main/revic_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Create a simple line plot
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40,50]
y = [10,200,10,1,2]

plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('larning point of view')
plt.show()

# %% [markdown]
# ###**Types of plot**
#
#
# 1.   Line plot
# 2.   Bar Chart
# 3. histrogram
# 4.  Scatter Plot

# %% [markdown]
# ##**LINE Plot**
# *A line plot is one of the most basic types of plots. It is used to display information as a series of data points connected by straight line segments.*

# %%
#Line Plot
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7]
y=[11,22,33,44,55,66,77]
plt.xlabel('x_axis')
plt.ylabel('y_axix')
plt.title('Line Plot')
plt.plot(x,y)
plt.show()

# %% [markdown]
# **Line plots are particularly useful for visualizing trends over time or continuous data. For example, you could use a line plot to show how a stock price changes over a year.**

# %% [markdown]
# ###**BAR CHART**

# %% [markdown]
# *Bar charts are useful for comparing different groups or tracking changes over time.*
#
# *Bar charts can be used in various scenarios, such as comparing the sales of different products or the performance of different teams. The height of each bar represents the value of the corresponding category, making it easy to compare different groups.*

# %%
Catagories = ["A","B","C","D"]
values = [4,2,4,1]
plt.bar(Catagories,values)
plt.ylabel('value')
plt.xlabel('catagories')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# **Histogram**
# *histogreams are used to represent the distribution of a dataset*

# %%
import numpy as np
import matplotlib.pyplot as plt   # ← You forgot this

# Sample data
data = np.random.randn(1000)

plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()
